# %%
# Work with Data - the main Python libraries
import numpy as np
import pandas as pd
import pandas_profiling as pp

# Visualization
import matplotlib.pyplot as plt

# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, ShuffleSplit, GridSearchCV

# Modeling
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from xgboost.sklearn import XGBRegressor

# Metrics
from sklearn.metrics import r2_score

import warnings
warnings.simplefilter('ignore')

import math
# Out:
# /tmp/ipykernel_24788/2689528378.py:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %%
pd.set_option('max_colwidth', 200)

# %%
data = pd.read_csv('./kaggle_data/PB_All_2000_2021.csv', sep=';', header=0)
data
# Out:
#       id        date    NH4  BSK5  Suspended     O2    NO3    NO2     SO4  \
# 0      1  17.02.2000  0.330  2.77       12.0  12.30   9.50  0.057  154.00
# 1      1  11.05.2000  0.044  3.00       51.6  14.61  17.75  0.034  352.00
# 2      1  11.09.2000  0.032  2.10       24.5   9.87  13.80  0.173  416.00
# 3      1  13.12.2000  0.170  2.23       35.6  12.40  17.13  0.099  275.20
# 4      1  02.03.2001  0.000  3.03       48.8  14.69  10.00  0.065  281.60
# ...   ..         ...    ...   ...        ...    ...    ...    ...     ...
# 2856  22  06.10.2020  0.046  2.69        3.6   8.28   3.80  0.038  160.00
# 2857  22  27.10.2020  0.000  1.52        0.5  11.26   0.56  0.031  147.20
# 2858  22  03.12.2020  0.034  0.29        0.8  11.09   2.58  0.042  209.92
# 2859  22  12.01.2021  0.000  2.10        0.0  14.31   3.94  0.034  121.60
# 2860  22  10.02.2021  0.000  1.78        0.0  14.30   6.30  0.033  134.40
#
#         PO4       CL
# 0     0.454   289.50
# 1     0.090  1792.00
# 2     0.200  2509.00
# 3     0.377  1264.00
# 4     0.134  1462.00
# ...     ...      ...
# 2856  0.726    77.85
# 2857  0.634    71.95
# 2858  0.484    61.17
# 2859  0.424    63.49
# 2860  0.582    66.31
#
# [2861 rows x 11 columns]

# %%
# Information for training data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2861 non-null   int64
#  1   date       2861 non-null   object
#  2   NH4        2858 non-null   float64
#  3   BSK5       2860 non-null   float64
#  4   Suspended  2845 non-null   float64
#  5   O2         2858 non-null   float64
#  6   NO3        2860 non-null   float64
#  7   NO2        2858 non-null   float64
#  8   SO4        2812 non-null   float64
#  9   PO4        2833 non-null   float64
#  10  CL         2812 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 246.0+ KB

# %%
# Download data about monitoring stations
data_about = pd.read_csv('./kaggle_data/PB_stations.csv', sep=';', header=0, encoding='cp1251')
data_about.sort_values(by=['length'], ascending=False)
# Out:
#     id  length  \
# 20  21   773.0
# 19  20   755.0
# 18  19   744.0
# 17  18   711.0
# 16  17   692.0
# 15  16   652.0
# 14  15   607.0
# 13  14   582.0
# 12  13   569.5
# 11  12   537.0
# 9   10   413.0
# 8    9   400.0
# 7    8   372.0
# 6    7   327.0
# 5    6   316.0
# 4    5   237.0
# 3    4   206.0
# 2    3   153.0
# 1    2   136.0
# 21  22    97.0
# 10  11    50.0
# 0    1     0.5
#
#                                                                                                                name_station
# 20                                                         р. Південний Буг, 773 км, смт. Чорний Острів, Мар'янівське вдсх.
# 19                                                            р. Південний Буг, 755 км, м. Хмельницький , Хмельницьке вдсх.
# 18                                                              р. Південний Буг, 744 км, с. Копистин, нижче м.Хмельницький
# 17                                                             р. Південний Буг, 711 км,  смт. Меджибіж, Меджибіжське вдсх.
# 16                                                                   р. Південний Буг, 692 км, с. Щедрове, Щедрівське вдсх.
# 15                                                            р. Південний Буг, 652 км, м. Хмільник, питний в/з, вище міста
# 14                                          р. Південний Буг, 607 км, с. Гущинці, нижче села , питний водозабір м.Калинівка
# 13                                    р. Південний Буг, 582 км, м. Вінниця, Сабарівське вдсх,  питний в/з міста, вище міста
# 12   р. Південний Буг, 569,5 км, 500 м нижче скиду ВОКВП ВКГ "Вінницяводоканал"   (1,5 км нижче греблі Сабарівського вдсх.)
# 11                                                           р. Південний Буг, 537 км, смт. Сутиски, Сутиське вдсх., н/б'єф
# 9                                                   р. Південний Буг, 413 км, с. Маньківка, вище села, питний в/з м.Ладижин
# 8                                                                   р. Південний Буг, 400 км, м. Ладижин, Ладижинське вдсх.
# 7                                                                 р. Південний Буг, 372 км, с. Глибочок, Глибочекське вдсх.
# 6                                            р. Південний Буг, 327 км, с. Ставки, кордон Вінницької та Кіровоградської обл.
# 5                                                                  р. Південний Буг, 316 км, м.Гайворон, Гайворонське вдсх.
# 4                                                                   р. Південний Буг, 237 км, питний водозабір смт Побузьке
# 3                                                              р. Південний Буг, 206 км, м. Первомайськ, Первомайське вдсх.
# 2                                                 р. Південний Буг, 153 км, с. Олексіівка, питний в/з м. Південно-Українськ
# 1                                                         р. Південний Буг, 136 км, с. Олександрівка, Олександрівське вдсх.
# 21  р. Південний Буг, 97 км, м. Вознесенськ, пит.в/з м. Вознесенськ, 2 км до в'їзду у м. Вознесенськ по трасі з м. Миколаїв
# 10                                                                р. Південний Буг, 50 км, с. Ковалівка, Південно-Бузька ЗС
# 0           р. Південний Буг, 0,5 км, м. Миколаїв, Бузький лиман, тех. в/з Миколаївської ТЕЦ (ліва частина морського порту)

# %%
data['id'].value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['ds'] = pd.to_datetime(data['date'])
data['year'] = data['ds'].dt.year
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2861 non-null   int64
#  1   date       2861 non-null   object
#  2   NH4        2858 non-null   float64
#  3   BSK5       2860 non-null   float64
#  4   Suspended  2845 non-null   float64
#  5   O2         2858 non-null   float64
#  6   NO3        2860 non-null   float64
#  7   NO2        2858 non-null   float64
#  8   SO4        2812 non-null   float64
#  9   PO4        2833 non-null   float64
#  10  CL         2812 non-null   float64
#  11  ds         2861 non-null   datetime64[ns]
#  12  year       2861 non-null   int64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(1)
# memory usage: 290.7+ KB

# %%
date_lim = pd.concat([data[['id', 'year']].groupby(by=['id']).min().sort_values(by=['year'], ascending=False), data[['id', 'year']].groupby(by=['id']).max().sort_values(by=['year'], ascending=False)], axis=1, join='outer')

# %%
date_lim
# Out:
#     year  year
# id
# 5   2019  2021
# 13  2006  2018
# 1   2000  2018
# 21  2000  2018
# 20  2000  2018
# 19  2000  2018
# 18  2000  2018
# 17  2000  2018
# 16  2000  2021
# 15  2000  2021
# 14  2000  2021
# 12  2000  2018
# 2   2000  2018
# 11  2000  2018
# 10  2000  2021
# 9   2000  2018
# 8   2000  2018
# 7   2000  2018
# 6   2000  2018
# 4   2000  2018
# 3   2000  2021
# 22  2000  2021

# %%
last_entries = {}
for index, row in date_lim.iterrows():
    last_entries[index] = (row[1])
new_entries = {}
for index, row in date_lim.iterrows():
    new_entries[index] = (row[0])

# %%
last_entries
# Out:
# {5: 2021,
#  13: 2018,
#  1: 2018,
#  21: 2018,
#  20: 2018,
#  19: 2018,
#  18: 2018,
#  17: 2018,
#  16: 2021,
#  15: 2021,
#  14: 2021,
#  12: 2018,
#  2: 2018,
#  11: 2018,
#  10: 2021,
#  9: 2018,
#  8: 2018,
#  7: 2018,
#  6: 2018,
#  4: 2018,
#  3: 2021,
#  22: 2021}

# %%
numerical_cols = data.select_dtypes(include=['int', 'float']).columns[1:-1]

normalized_data = data.copy()

normalized_data[numerical_cols] = (data[numerical_cols] - data[numerical_cols].min()) / (data[numerical_cols].max() - data[numerical_cols].min())

# %%
normalized_data
# Out:
#       id        date       NH4      BSK5  Suspended        O2       NO3  \
# 0      1  17.02.2000  0.008370  0.054420   0.020168  0.136667  0.071214
# 1      1  11.05.2000  0.001116  0.058939   0.086723  0.162333  0.133058
# 2      1  11.09.2000  0.000812  0.041257   0.041176  0.109667  0.103448
# 3      1  13.12.2000  0.004312  0.043811   0.059832  0.137778  0.128411
# 4      1  02.03.2001  0.000000  0.059528   0.082017  0.163222  0.074963
# ...   ..         ...       ...       ...        ...       ...       ...
# 2856  22  06.10.2020  0.001167  0.052849   0.006050  0.092000  0.028486
# 2857  22  27.10.2020  0.000000  0.029862   0.000840  0.125111  0.004198
# 2858  22  03.12.2020  0.000862  0.005697   0.001345  0.123222  0.019340
# 2859  22  12.01.2021  0.000000  0.041257   0.000000  0.159000  0.029535
# 2860  22  10.02.2021  0.000000  0.034971   0.000000  0.158889  0.047226
#
#            NO2       SO4       PO4        CL         ds  year
# 0     0.000523  0.043096  0.032711  0.051552 2000-02-17  2000
# 1     0.000312  0.098506  0.006485  0.319127 2000-11-05  2000
# 2     0.001587  0.116416  0.014410  0.446815 2000-11-09  2000
# 3     0.000908  0.077013  0.027163  0.225097 2000-12-13  2000
# 4     0.000596  0.078804  0.009655  0.260358 2001-02-03  2001
# ...        ...       ...       ...       ...        ...   ...
# 2856  0.000349  0.044775  0.052309  0.013860 2020-06-10  2020
# 2857  0.000284  0.041193  0.045681  0.012810 2020-10-27  2020
# 2858  0.000385  0.058745  0.034873  0.010890 2020-03-12  2020
# 2859  0.000312  0.034029  0.030550  0.011303 2021-12-01  2021
# 2860  0.000303  0.037611  0.041934  0.011805 2021-10-02  2021
#
# [2861 rows x 13 columns]

# %%
fields = list(normalized_data.columns[2:11])
dict_data = {}

vec = {}
vec = [np.nan]*12
    
for index, row in normalized_data.iterrows():
    curr_id = int(row['id'])
    curr_year = int(row['year'])
    
    if dict_data[(curr_id, curr_year,k)] == np.nan:
        print(curr_id, curr_year, k)
    
    for k in fields:
        dict_data[(curr_id, curr_year, k)] = vec
    
    
for index, row in normalized_data.iterrows():
    curr_id = int(row['id'])
    curr_year = int(row['year'])
    curr_month = int(row['ds'].month)-1
    
    if dict_data[(curr_id, curr_year,k)] == np.nan:
        print(curr_id, curr_year, k)
    
    for k in fields:
        dict_data[(curr_id, curr_year,k)][curr_month] = row[k]
        
        if(k == 'NH4' and curr_id == 1 and curr_year == 2008):
            print(curr_month)
            print(dict_data[(curr_id, curr_year,k)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 7>()
#       8 curr_id = int(row['id'])
#       9 curr_year = int(row['year'])
# ---> 11 if dict_data[(curr_id, curr_year,k)] == np.nan:
#      12     print(curr_id, curr_year, k)
#      14 for k in fields:
#
# KeyError: (1, 2000, 'CL')

# %%
dict_data[(1, 2008, 'NH4')]
# Out:
# [0.011178467248177289,
#  0.011251482567147381,
#  0.010889967695173511,
#  0.011137507435096505,
#  0.010889967695173511,
#  0.013860444574249457,
#  0.011632586914942499,
#  0.013043029174072086,
#  0.01306261864989333,
#  0.011805330474457107,
#  0.012433974562175218,
#  0.011303127548857934]

# %%
dict_data[(2, 2009, 'NH4')]
# Out:
# [0.011178467248177289,
#  0.011251482567147381,
#  0.010889967695173511,
#  0.011137507435096505,
#  0.010889967695173511,
#  0.013860444574249457,
#  0.011632586914942499,
#  0.013043029174072086,
#  0.01306261864989333,
#  0.011805330474457107,
#  0.012433974562175218,
#  0.011303127548857934]

# %%
len(dict_data)
# Out:
# 3663

# %%
for key, value in dict_data.items():
    for element in value:
        if math.isnan(element):
            print(f"Found NaN in {key}!")

# %%
for index, row in normalized_data.iterrows():
    curr_id = row['id']
    curr_year = row['year']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.optim.lr_scheduler as lscheduler

# %%
feature  = "NH4"
train_data  = []
test_data = []
for i,j,k in dict_data.keys():
    if feature == k:
        if j == last_entries[i] :
            test_data.append(dict_data[(i,j,k)])
        train_data.append(dict_data[(i,j,k)])

# %%
print(len(train_data))
print(len(test_data))
# Out:
# 407
# 22

# %%
class AirModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=50, num_layers=1, batch_first=True)
        self.linear = nn.Linear(50, 1)
    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        x = self.linear(lstm_out)
        return x

# %%
def yearly_data(data,feature, station):
    out = []
    k_f = feature
    i_f = station
    start_year = new_entries[i_f]
    end_year = last_entries[i_f]
    for i in range(start_year, end_year+1):
        if (i_f, i, k_f) in dict_data.keys():
            out= out + list(data[(i_f,i,k_f)])
    return out

# %%
model = AirModel().to('cuda')

# %%
def create_dataset(dataset, lookback):
    """Transform a time series into a prediction dataset
    
    Args:
        dataset: A numpy array of time series, first dimension is the time steps
        lookback: Size of window for prediction
    """
    X, y = [], []
    for i in range(len(dataset)-lookback):
        feature = dataset[i:i+lookback]
        target = dataset[i+1:i+lookback+1]
        X.append(feature)
        y.append(target)
    return torch.tensor(X).reshape(-1, lookback, 1), torch.tensor(y).reshape(-1, lookback, 1)

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.MSELoss()
scheduler = lscheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

# %%
n_epochs = 100
test_loss = []
train_loss = []
look= 12
btch=2
for epoch in range(n_epochs):
    avg_loss = 0
    vavg_loss = 0
    for station_id in list(set(normalized_data['id'])):
        
        data_seq_nh4 = yearly_data(dict_data, 'NH4', station_id)

        train_nh4 = data_seq_nh4[:180]
        test_nh4 = data_seq_nh4[180:]
        
        trainX, trainY = create_dataset(train_nh4, look)
        testX, testY = create_dataset(train_nh4, look)
        
        loader = data.DataLoader(data.TensorDataset(trainX, trainY), shuffle=True, batch_size=btch)
        valloader = data.DataLoader(data.TensorDataset(testX, testY), shuffle=True, batch_size=btch)
        
        model.train()
  
        for X_batch, y_batch in loader:
            y_pred = model(X_batch.to('cuda'))
            loss = loss_fn(y_pred, y_batch.to('cuda'))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            avg_loss += loss.sum().item()
            
        for X_batch, y_batch in valloader:
            with torch.no_grad():
                y_pred = model(X_batch.to('cuda'))
                loss = loss_fn(y_pred, y_batch.to('cuda'))
                vavg_loss += loss.sum().item()

    if epoch % 1 != 0:
        continue
    scheduler.step(avg_loss)
    train_loss.append(avg_loss)
    test_loss.append(vavg_loss)

    print("Epoch %d: avg loss: %.6f , test: %0.6f" % (epoch, avg_loss, vavg_loss))
# Out:
# Epoch 0: avg loss: 0.068599 , test: 0.015491
# Epoch 1: avg loss: 0.001626 , test: 0.001611
# Epoch 2: avg loss: 0.001661 , test: 0.001628
# Epoch 3: avg loss: 0.001715 , test: 0.001709
# Epoch 4: avg loss: 0.001705 , test: 0.001683
# Epoch 5: avg loss: 0.001654 , test: 0.001652
# Epoch 6: avg loss: 0.001631 , test: 0.001616
# Epoch 7: avg loss: 0.001588 , test: 0.001583
# Epoch 8: avg loss: 0.001524 , test: 0.001525
# Epoch 9: avg loss: 0.001378 , test: 0.001334
# Epoch 10: avg loss: 0.001225 , test: 0.001225
# Epoch 11: avg loss: 0.001200 , test: 0.001188
# Epoch 12: avg loss: 0.001146 , test: 0.001153
# Epoch 13: avg loss: 0.001116 , test: 0.001065
# Epoch 14: avg loss: 0.001088 , test: 0.001134
# Epoch 15: avg loss: 0.001084 , test: 0.001070
# Epoch 16: avg loss: 0.001082 , test: 0.001057
# Epoch 17: avg loss: 0.001074 , test: 0.001094
# Epoch 18: avg loss: 0.001068 , test: 0.001087
# Epoch 19: avg loss: 0.001072 , test: 0.001139
# Epoch 20: avg loss: 0.001058 , test: 0.001026
# Epoch 21: avg loss: 0.001063 , test: 0.001072
# Epoch 22: avg loss: 0.001043 , test: 0.001069
# Epoch 23: avg loss: 0.001059 , test: 0.001037
# Epoch 24: avg loss: 0.001042 , test: 0.001032
# Epoch 25: avg loss: 0.001045 , test: 0.001080
# Epoch 26: avg loss: 0.001040 , test: 0.001029
# Epoch 27: avg loss: 0.001045 , test: 0.001012
# Epoch 28: avg loss: 0.001028 , test: 0.001016
# Epoch 29: avg loss: 0.001038 , test: 0.000993
# Epoch 30: avg loss: 0.001021 , test: 0.000993
# Epoch 31: avg loss: 0.001021 , test: 0.001047
# Epoch 32: avg loss: 0.001022 , test: 0.001002
# Epoch 33: avg loss: 0.001024 , test: 0.000993
# Epoch 34: avg loss: 0.001022 , test: 0.001002
# Epoch 35: avg loss: 0.001013 , test: 0.001014
# Epoch 36: avg loss: 0.001016 , test: 0.000993
# Epoch 37: avg loss: 0.001007 , test: 0.001011
# Epoch 38: avg loss: 0.001012 , test: 0.001013
# Epoch 39: avg loss: 0.001003 , test: 0.000999
# Epoch 40: avg loss: 0.000989 , test: 0.000955
# Epoch 41: avg loss: 0.000987 , test: 0.001003
# Epoch 42: avg loss: 0.000989 , test: 0.000947
# Epoch 43: avg loss: 0.000974 , test: 0.000940
# Epoch 44: avg loss: 0.000967 , test: 0.000969
# Epoch 45: avg loss: 0.000963 , test: 0.000972
# Epoch 46: avg loss: 0.000960 , test: 0.000959
# Epoch 47: avg loss: 0.000938 , test: 0.000932
# Epoch 48: avg loss: 0.000935 , test: 0.000944
# Epoch 49: avg loss: 0.000949 , test: 0.000940
# Epoch 50: avg loss: 0.000949 , test: 0.000951
# Epoch 51: avg loss: 0.000922 , test: 0.000903
# Epoch 52: avg loss: 0.000908 , test: 0.000937
# Epoch 53: avg loss: 0.000835 , test: 0.000816
# Epoch 54: avg loss: 0.000809 , test: 0.000778
# Epoch 55: avg loss: 0.000793 , test: 0.000777
# Epoch 56: avg loss: 0.000790 , test: 0.000813
# Epoch 57: avg loss: 0.000785 , test: 0.000771
# Epoch 58: avg loss: 0.000785 , test: 0.000739
# Epoch 59: avg loss: 0.000773 , test: 0.000795
# Epoch 60: avg loss: 0.000780 , test: 0.000770
# Epoch 61: avg loss: 0.000771 , test: 0.000743
# Epoch 62: avg loss: 0.000766 , test: 0.000774
# Epoch 63: avg loss: 0.000758 , test: 0.000754
# Epoch 64: avg loss: 0.000763 , test: 0.000776
# Epoch 65: avg loss: 0.000755 , test: 0.000719
# Epoch 66: avg loss: 0.000748 , test: 0.000756
# Epoch 67: avg loss: 0.000728 , test: 0.000717
# Epoch 68: avg loss: 0.000701 , test: 0.000704
# Epoch 69: avg loss: 0.000676 , test: 0.000664
# Epoch 70: avg loss: 0.000635 , test: 0.000626
# Epoch 71: avg loss: 0.000613 , test: 0.000586
# Epoch 72: avg loss: 0.000583 , test: 0.000588
# Epoch 73: avg loss: 0.000565 , test: 0.000579
# Epoch 74: avg loss: 0.000544 , test: 0.000549
# Epoch 75: avg loss: 0.000542 , test: 0.000561
# Epoch 76: avg loss: 0.000525 , test: 0.000522
# Epoch 77: avg loss: 0.000522 , test: 0.000506
# Epoch 78: avg loss: 0.000517 , test: 0.000538
# Epoch 79: avg loss: 0.000505 , test: 0.000490
# Epoch 80: avg loss: 0.000510 , test: 0.000520
# Epoch 81: avg loss: 0.000509 , test: 0.000490
# Epoch 82: avg loss: 0.000491 , test: 0.000500
# Epoch 83: avg loss: 0.000489 , test: 0.000473
# Epoch 84: avg loss: 0.000485 , test: 0.000482
# Epoch 85: avg loss: 0.000494 , test: 0.000527
# Epoch 86: avg loss: 0.000482 , test: 0.000477
# Epoch 87: avg loss: 0.000485 , test: 0.000454
# Epoch 88: avg loss: 0.000475 , test: 0.000480
# Epoch 89: avg loss: 0.000483 , test: 0.000468
# Epoch 90: avg loss: 0.000470 , test: 0.000451
# Epoch 91: avg loss: 0.000476 , test: 0.000514
# Epoch 92: avg loss: 0.000476 , test: 0.000477
# Epoch 93: avg loss: 0.000461 , test: 0.000471
# Epoch 94: avg loss: 0.000459 , test: 0.000446
# Epoch 95: avg loss: 0.000466 , test: 0.000462
# Epoch 96: avg loss: 0.000460 , test: 0.000449
# Epoch 97: avg loss: 0.000463 , test: 0.000447
# Epoch 98: avg loss: 0.000455 , test: 0.000445
# Epoch 99: avg loss: 0.000452 , test: 0.000437

# %%
plt.plot(train_loss[20:], '-bo')

# %%
plt.plot(test_loss[20:], '-bo')

# %%
len(test_nh4)

plt.plot(data_seq_nh4)

# %%
test_nh4[:12]
# Out:
# [0.011178467248177289,
#  0.011251482567147381,
#  0.010889967695173511,
#  0.011137507435096505,
#  0.010889967695173511,
#  0.013860444574249457,
#  0.011632586914942499,
#  0.013043029174072086,
#  0.01306261864989333,
#  0.011805330474457107,
#  0.012433974562175218,
#  0.011303127548857934]

# %%
test_nh4[12:24]
# Out:
# [0.011178467248177289,
#  0.011251482567147381,
#  0.010889967695173511,
#  0.011137507435096505,
#  0.010889967695173511,
#  0.013860444574249457,
#  0.011632586914942499,
#  0.013043029174072086,
#  0.01306261864989333,
#  0.011805330474457107,
#  0.012433974562175218,
#  0.011303127548857934]
